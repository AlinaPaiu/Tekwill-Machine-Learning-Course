# %% [markdown]
# # Funcții și metode Temă pentru acasă
#
# Implementati urmatoarele sarcini:
# ____
# **Scrieți o funcție care să calculeze volumul unei sfere, dată fiind raza acesteia.**
#
# <p>Volumul unei sfere este dat de formula $$\frac{4}{3} πr^3$$</p>

# %%
def volumul(r):
  pi = 3.14
  return (4.0/3)*pi*(r**3)

# %%
# Verificam
volumul(2)
# Out:
# 33.49333333333333

# %% [markdown]
# ___
# **Scrieți o funcție care să verifice dacă un număr se află într-un interval dat (inclusiv valorile mare și mică)**

# %%
def este_in_interval(num, low, high):
    
    # Check if num is between low and high (including low and high)
    if num in range(low,high+1):
        print('Nr {} este in intervalul [{}, {}]'.format(num,low,high))
    else:
        print('Acest numar este inafara intervalului.')

# %%
este_in_interval(5,2,7)
# Out:
# Nr 5 este in intervalul [2, 7]

# %% [markdown]
# ____
# **Scrieți o funcție Python care acceptă un șir de caractere și calculează numărul de litere majuscule și minuscule.**
#
#     Exemplu de String : 'Hello Mr. Rogers, how are you this fine Tuesday?'
#     Rezulat asteptat :
#     Nr de majuscule : 4
#     Nr de minuscule : 33
#
# SUGESTIE: Două metode de string care s-ar putea dovedi utile: **.isupper()** and **.islower()**

# %%
def numara_majuscule_minuscule(s):
    d={'upper':0, 'lower':0}
    for c in s:
        if c.isupper():
            d['upper']+=1
        elif c.islower():
            d['lower']+=1
        else:
            pass
    print('String-ul original : ', s)
    print('Nr de majuscule : ', d['upper'])
    print('Nr de minuscule : ', d['lower'])

# %%
s = 'Hello Mr. Rogers, how are you this fine Tuesday?'
numara_majuscule_minuscule(s)
# Out:
# String-ul original :  Hello Mr. Rogers, how are you this fine Tuesday?
# Nr de majuscule :  4
# Nr de minuscule :  33

# %%
s = 'Salut. Bine ai venit la acest curs. Cum te simti?'
numara_majuscule_minuscule(s)
# Out:
# String-ul original :  Salut. Bine ai venit la acest curs. Cum te simti?
# Nr de majuscule :  3
# Nr de minuscule :  34

# %% [markdown]
# ____
# **Scrieți o funcție Python care ia o listă și returnează o nouă listă cu elemente unice ale primei liste.**
#
#     Sample List : [1,1,1,1,2,2,3,3,3,3,4,5]
#     Unique List : [1, 2, 3, 4, 5]

# %%
def lista_unica(l):
    x = []
    for a in l:
        if a not in x:
            x.append(a)
    return x

# %%
lista_unica([1,1,1,1,2,2,3,3,3,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ____
# **Scrieți o funcție Python care să înmulțească toate numerele dintr-o listă.**
#
#     Sample List : [1, 2, 3, -4]
#     Expected Output : -24

# %%
def multiply(numbers):  
    total = numbers[0]
    for x in numbers:
        total *= x
    return total

# %%
multiply([1,2,3,-4])
# Out:
# -24

# %% [markdown]
# ____
# **Scrieți o funcție Python care să verifice dacă un șir de caractere transmis este sau nu palindrom.**
#
# Notă: Un palindrom este un cuvânt, o frază sau o secvență care se citește la fel si în sens invers, de exemplu, madam sau ana.

# %%
def palindrome(s):
    return s == s[::-1]

# %%
palindrome("madam")
# Out:
# True

# %%
palindrome("adam")

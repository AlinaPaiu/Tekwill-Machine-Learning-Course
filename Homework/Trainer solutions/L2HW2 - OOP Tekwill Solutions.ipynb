# %% [markdown]
# # Programare orientată pe obiecte
# ## Tema pentru acasă
#
# #### Problema 1
# Completați metodele clasei Linie pentru a accepta coordonatele ca o pereche de tupluri și pentru a returna panta și distanța liniei.
#
# slope: m=(delta Y)/(delta X) ![image.png](data:image/png;base64,...)
# euclidean distance: ![image.png](data:image/png;base64,...)

# %%
class Line:
    
    def __init__(self,coor1,coor2):
        self.coor1 = coor1
        self.coor2 = coor2
    
    def distance(self):
        
        x1, y1 = self.coor1
        x2, y2 = self.coor2
        
        return((x2-x1)**2 + (y2-y1)**2)**0.5
    
    def slope(self):
        
        x1, y1 = self.coor1
        x2, y2 = self.coor2
        
        return (y2-y1) / (x2-x1)

# %%
# EXAMPLE OUTPUT

coordinate1 = (16,25)
coordinate2 = (4,5)

li = Line(coordinate1,coordinate2)

# %%
li.distance()
# Out:
# 23.323807579381203

# %%
li.slope()
# Out:
# 1.6

# %% [markdown]
# ________
# #### Problema 2

# %% [markdown]
# Completați clasa

# %%
class Cylinder:
    
    def __init__(self,height=1,radius=1):
        
        self.height = height
        self.radius = radius
        
    def volume(self):
        return self.height * 3.14 * (self.radius)**2
    
    def surface_area(self):
        
        top = 3.14 * (self.radius**2)
        
        return (2*top) + (2*3.14*self.radius*self.height)

# %%
# EXAMPLE OUTPUT
c = Cylinder(2,3)

# %%
c.volume()
# Out:
# 56.52

# %%
c.surface_area()
# Out:
# 94.2
